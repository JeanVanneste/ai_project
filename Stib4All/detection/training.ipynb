# %%
import os
from pathlib import Path
from ultralytics import YOLO
import torch
import yaml
from PIL import Image
import shutil

print(f"PyTorch version: {torch.__version__}")
print(f"CUDA available: {torch.cuda.is_available()}")
if torch.cuda.is_available():
    print(f"CUDA device: {torch.cuda.get_device_name(0)}")
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/home/jean/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.
# PyTorch version: 2.9.1+cu128
# CUDA available: False

# %%
DATASET_WHEELCHAIR_PATH = Path("Wheelchair-1")
PROJECT_DIR = Path("")
DATASET_DIR = PROJECT_DIR / "dataset"

PROJECT_DIR.mkdir(exist_ok=True)
DATASET_DIR.mkdir(exist_ok=True)

print(f"Using local dataset: {DATASET_WHEELCHAIR_PATH.absolute()}")
# Out:
# Using local dataset: /home/jean/dev/ai_project/Stib4All/detection/Wheelchair-1

# %%
# %pwd
# Out:
# '/home/jean/dev/ai_project/Stib4All/detection'

# %%
classes_file = DATASET_WHEELCHAIR_PATH / "classes.txt"
if classes_file.exists():
    with open(classes_file, "r", encoding="utf-8") as f:
        class_names = [line.strip() for line in f.readlines()]
    print(f"✓ Classes found: {class_names}")
    print(f"✓ Number of classes: {len(class_names)}")
else:
    print(f"⚠️ classes.txt not found at {classes_file}")
    class_names = []

image_files = list(DATASET_WHEELCHAIR_PATH.glob("**/*.jpeg")) + list(DATASET_WHEELCHAIR_PATH.glob("**/*.jpg"))
label_files = [f for f in DATASET_WHEELCHAIR_PATH.glob("**/*.txt") if f.name != "classes.txt"]

print(f"Total images found: {len(image_files)}")
print(f"Total label files found: {len(label_files)}")
# Out:
# ✓ Classes found: ['wheelchair']
# ✓ Number of classes: 1
# Total images found: 417
# Total label files found: 417

# %%
# Verify the dataset structure
print("Dataset structure verification:")
print(f"  Train images: {DATASET_WHEELCHAIR_PATH / 'train' / 'images'}")
print(f"  Train labels: {DATASET_WHEELCHAIR_PATH / 'train' / 'labels'}")
print(f"  Valid images: {DATASET_WHEELCHAIR_PATH / 'test' / 'images'}")
print(f"  Valid labels: {DATASET_WHEELCHAIR_PATH / 'test' / 'labels'}")

# Count files
print(DATASET_WHEELCHAIR_PATH / 'train' / 'images')
train_imgs = len(list((DATASET_WHEELCHAIR_PATH / 'train' / 'images').glob('*')))
train_lbls = len(list((DATASET_WHEELCHAIR_PATH / 'train' / 'labels').glob('*')))
val_imgs = len(list((DATASET_WHEELCHAIR_PATH / 'test' / 'images').glob('*')))
val_lbls = len(list((DATASET_WHEELCHAIR_PATH / 'test' / 'labels').glob('*')))

print(f"\n✓ Files in dataset:")
print(f"  Training: {train_imgs} images, {train_lbls} labels")
print(f"  Validation: {val_imgs} images, {val_lbls} labels")
# Out:
# Dataset structure verification:
#   Train images: Wheelchair-1/train/images
#   Train labels: Wheelchair-1/train/labels
#   Valid images: Wheelchair-1/test/images
#   Valid labels: Wheelchair-1/test/labels
# Wheelchair-1/train/images
#
# ✓ Files in dataset:
#   Training: 362 images, 362 labels
#   Validation: 55 images, 55 labels

# %%
# Define your dataset configuration using the local dataset
data_config = {
    'path': str(DATASET_WHEELCHAIR_PATH.absolute()),  # Root directory
    'train': 'train/images',  # Path to training images
    'val': 'test/images',    # Path to validation images
    'nc': len(class_names),   # Number of classes from classes.txt
    'names': class_names      # Class names from classes.txt
}

# Save configuration to YAML file
yaml_path = DATASET_WHEELCHAIR_PATH / 'data.yaml'
with open(yaml_path, 'w', encoding='utf-8') as f:
    yaml.dump(data_config, f, default_flow_style=False, allow_unicode=True)

print(f"✓ Configuration saved to: {yaml_path}")
print("\nDataset configuration:")
print(yaml.dump(data_config, default_flow_style=False, allow_unicode=True))
# Out:
# ✓ Configuration saved to: Wheelchair-1/data.yaml
#
# Dataset configuration:
# names:
# - wheelchair
# nc: 1
# path: /home/jean/dev/ai_project/Stib4All/detection/Wheelchair-1
# train: train/images
# val: test/images

# %% [markdown]
# # Load and train model

# %%
# Load a pre-trained YOLOv8 model
# Start with yolov8n (nano) for faster training, or use yolov8m/yolov8l for better accuracy
model = YOLO('yolov8s.pt')  # Automatically downloads if not present

print("Model loaded successfully!")
print(f"Model type: {type(model)}")

# Display model information
model.info()  # Shows model architecture details
# Out:
# Downloading https://github.com/ultralytics/assets/releases/download/v8.3.0/yolov8s.pt to 'yolov8s.pt': 100% ━━━━━━━━━━━━ 21.5MB 22.7MB/s 0.9s 0.9s<0.0s
# Model loaded successfully!
# Model type: <class 'ultralytics.models.yolo.model.YOLO'>
# YOLOv8s summary: 129 layers, 11,166,560 parameters, 0 gradients, 28.8 GFLOPs
# (129, 11166560, 0, 28.816844800000002)

# %%
# Training configuration
training_args = {
    'data': str(yaml_path),      # Path to data.yaml
    'epochs': 50,                # Number of epochs (adjust based on dataset size)
    'imgsz': 640,                # Image size
    'batch': 16,                 # Batch size (reduce if GPU memory is limited)
    'patience': 10,              # Early stopping patience
    'save': True,                # Save checkpoints
    'device': 0 if torch.cuda.is_available() else 'cpu',  # Use GPU if available
    'project': str(PROJECT_DIR), # Project directory
    'name': 'yolov8_custom',     # Experiment name
    'exist_ok': True,            # Overwrite existing project
    'pretrained': True,          # Use pretrained weights
    'optimizer': 'AdamW',        # Optimizer (SGD, Adam, AdamW)
    'lr0': 0.001,                # Initial learning rate
    'weight_decay': 0.0005,      # Weight decay
    'warmup_epochs': 3,          # Warmup epochs
    'augment': True,             # Use data augmentation
    'verbose': True,             # Verbose output
}

print("Training configuration:")
for key, value in training_args.items():
    print(f"  {key}: {value}")

print("\n⚠️ Note: Training may take several hours depending on dataset size and hardware!")
print("You can monitor progress in real-time through the console output.")
# Out:
# Training configuration:
#   data: Wheelchair-1/data.yaml
#   epochs: 50
#   imgsz: 640
#   batch: 16
#   patience: 10
#   save: True
#   device: cpu
#   project: .
#   name: yolov8_custom
#   exist_ok: True
#   pretrained: True
#   optimizer: AdamW
#   lr0: 0.001
#   weight_decay: 0.0005
#   warmup_epochs: 3
#   augment: True
#   verbose: True
#
# ⚠️ Note: Training may take several hours depending on dataset size and hardware!
# You can monitor progress in real-time through the console output.

# %%
# Start training with the local dataset
# Uncomment the following lines when you're ready to train
results = model.train(
    data=str(yaml_path),
    epochs=50,
    imgsz=640,
    batch=16,
    device=0 if torch.cuda.is_available() else 'cpu',
    project=str(PROJECT_DIR),
    name='yolov8_custom',
    exist_ok=True
)

print("✓ Training completed!")
print(f"Results saved to: {PROJECT_DIR / 'yolov8_custom'}")
# Out:
# New https://pypi.org/project/ultralytics/8.3.235 available 😃 Update with 'pip install -U ultralytics'
# Ultralytics 8.3.232 🚀 Python-3.12.3 torch-2.9.1+cu128 CPU (AMD Ryzen 5 7600X 6-Core Processor)
# engine/trainer: agnostic_nms=False, amp=True, augment=False, auto_augment=randaugment, batch=16, bgr=0.0, box=7.5, cache=False, cfg=None, classes=None, close_mosaic=10, cls=0.5, compile=False, conf=None, copy_paste=0.0, copy_paste_mode=flip, cos_lr=False, cutmix=0.0, data=Wheelchair-1/data.yaml, degrees=0.0, deterministic=True, device=cpu, dfl=1.5, dnn=False, dropout=0.0, dynamic=False, embed=None, epochs=50, erasing=0.4, exist_ok=True, fliplr=0.5, flipud=0.0, format=torchscript, fraction=1.0, freeze=None, half=False, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, imgsz=640, int8=False, iou=0.7, keras=False, kobj=1.0, line_width=None, lr0=0.01, lrf=0.01, mask_ratio=4, max_det=300, mixup=0.0, mode=train, model=yolov8s.pt, momentum=0.937, mosaic=1.0, multi_scale=False, name=yolov8_custom, nbs=64, nms=False, opset=None, optimize=False, optimizer=auto, overlap_mask=True, patience=100, perspective=0.0, plots=True, pose=12.0, pretrained=True, profile=False, project=., rect=False, resume=False, retina_masks=False, save=True, save_conf=False, save_crop=False, save_dir=/home/jean/dev/ai_project/Stib4All/detection/yolov8_custom, save_frames=False, save_json=False, save_period=-1, save_txt=False, scale=0.5, seed=0, shear=0.0, show=False, show_boxes=True, show_conf=True, show_labels=True, simplify=True, single_cls=False, source=None, split=val, stream_buffer=False, task=detect, time=None, tracker=botsort.yaml, translate=0.1, val=True, verbose=True, vid_stride=1, visualize=False, warmup_bias_lr=0.1, warmup_epochs=3.0, warmup_momentum=0.8, weight_decay=0.0005, workers=8, workspace=None
# Downloading https://ultralytics.com/assets/Arial.ttf to '/home/jean/.config/Ultralytics/Arial.ttf': 100% ━━━━━━━━━━━━ 755.1KB 10.7MB/s 0.1s
# Overriding model.yaml nc=80 with nc=1
#
#                    from  n    params  module                                       arguments
#   0                  -1  1       928  ultralytics.nn.modules.conv.Conv             [3, 32, 3, 2]
#   1                  -1  1     18560  ultralytics.nn.modules.conv.Conv             [32, 64, 3, 2]
#   2                  -1  1     29056  ultralytics.nn.modules.block.C2f             [64, 64, 1, True]
#   3                  -1  1     73984  ultralytics.nn.modules.conv.Conv             [64, 128, 3, 2]
#   4                  -1  2    197632  ultralytics.nn.modules.block.C2f             [128, 128, 2, True]
#   5                  -1  1    295424  ultralytics.nn.modules.conv.Conv             [128, 256, 3, 2]
#   6                  -1  2    788480  ultralytics.nn.modules.block.C2f             [256, 256, 2, True]
#   7                  -1  1   1180672  ultralytics.nn.modules.conv.Conv             [256, 512, 3, 2]
#   8                  -1  1   1838080  ultralytics.nn.modules.block.C2f             [512, 512, 1, True]
#   9                  -1  1    656896  ultralytics.nn.modules.block.SPPF            [512, 512, 5]
#  10                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  11             [-1, 6]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  12                  -1  1    591360  ultralytics.nn.modules.block.C2f             [768, 256, 1]
#  13                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  14             [-1, 4]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  15                  -1  1    148224  ultralytics.nn.modules.block.C2f             [384, 128, 1]
#  16                  -1  1    147712  ultralytics.nn.modules.conv.Conv             [128, 128, 3, 2]
#  17            [-1, 12]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  18                  -1  1    493056  ultralytics.nn.modules.block.C2f             [384, 256, 1]
#  19                  -1  1    590336  ultralytics.nn.modules.conv.Conv             [256, 256, 3, 2]
#  20             [-1, 9]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  21                  -1  1   1969152  ultralytics.nn.modules.block.C2f             [768, 512, 1]
#  22        [15, 18, 21]  1   2116435  ultralytics.nn.modules.head.Detect           [1, [128, 256, 512]]
# Model summary: 129 layers, 11,135,987 parameters, 11,135,971 gradients, 28.6 GFLOPs
#
# Transferred 349/355 items from pretrained weights
# Freezing layer 'model.22.dfl.conv.weight'
# train: Fast image access ✅ (ping: 0.0±0.0 ms, read: 111.0±30.5 MB/s, size: 57.2 KB)
# train: Scanning /home/jean/dev/ai_project/Stib4All/detection/Wheelchair-1/train/labels.cache... 362 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 362/362 696.5Kit/s 0.0s
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 104.0±25.8 MB/s, size: 51.7 KB)
# val: Scanning /home/jean/dev/ai_project/Stib4All/detection/Wheelchair-1/test/labels.cache... 55 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 55/55 156.2Kit/s 0.0s
# Plotting labels to /home/jean/dev/ai_project/Stib4All/detection/yolov8_custom/labels.jpg...
# optimizer: 'optimizer=auto' found, ignoring 'lr0=0.01' and 'momentum=0.937' and determining best 'optimizer', 'lr0' and 'momentum' automatically...
# optimizer: AdamW(lr=0.002, momentum=0.9) with parameter groups 57 weight(decay=0.0), 64 weight(decay=0.0005), 63 bias(decay=0.0)
# Image sizes 640 train, 640 val
# Using 0 dataloader workers
# Logging results to /home/jean/dev/ai_project/Stib4All/detection/yolov8_custom
# Starting training for 50 epochs...
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        1/50         0G     0.9503      1.874      1.428         24        640: 100% ━━━━━━━━━━━━ 23/23 5.5s/it 2:074.2ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 3.2s/it 6.3s<12.6s
#                    all         55         61      0.568      0.754      0.658      0.326
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        2/50         0G      0.889     0.9907      1.355         31        640: 100% ━━━━━━━━━━━━ 23/23 5.1s/it 1:574.1ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 2.8s/it 5.7s<11.1s
#                    all         55         61      0.476      0.426      0.394      0.152
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        3/50         0G      1.002     0.9861      1.439         23        640: 100% ━━━━━━━━━━━━ 23/23 4.8s/it 1:514.1ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 2.8s/it 5.6s<11.0s
#                    all         55         61      0.192      0.475      0.192     0.0586
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        4/50         0G      1.125      1.047      1.516         22        640: 100% ━━━━━━━━━━━━ 23/23 4.8s/it 1:504.1sss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 3.0s/it 6.0s<11.8s
#                    all         55         61      0.145       0.18     0.0859     0.0242
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        5/50         0G      1.163      1.069      1.526         25        640: 100% ━━━━━━━━━━━━ 23/23 4.9s/it 1:534.1ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 2.9s/it 5.8s<11.0s
#                    all         55         61      0.125     0.0164     0.0169    0.00406
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        6/50         0G      1.092     0.9827       1.48         22        640: 100% ━━━━━━━━━━━━ 23/23 4.8s/it 1:504.0sss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 2.9s/it 5.7s<11.1s
#                    all         55         61     0.0168      0.131    0.00924     0.0019
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        7/50         0G      1.112     0.9767      1.491         18        640: 100% ━━━━━━━━━━━━ 23/23 4.8s/it 1:494.0sss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 2.8s/it 5.7s<11.1s
#                    all         55         61      0.112      0.279     0.0587     0.0182
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        8/50         0G      1.058     0.9583      1.455         27        640: 100% ━━━━━━━━━━━━ 23/23 4.7s/it 1:494.1sss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 2.8s/it 5.7s<11.0s
#                    all         55         61      0.343      0.492      0.335      0.144
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        9/50         0G       1.06     0.9408      1.472         28        640: 100% ━━━━━━━━━━━━ 23/23 4.8s/it 1:504.0sss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 2.9s/it 5.9s<11.6s
#                    all         55         61      0.462      0.508      0.469      0.222
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       10/50         0G     0.9896     0.8752       1.41         24        640: 100% ━━━━━━━━━━━━ 23/23 5.1s/it 1:574.3ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 2.9s/it 5.7s<11.1s
#                    all         55         61       0.66      0.738      0.762      0.428
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       11/50         0G     0.9676     0.8411      1.376         26        640: 100% ━━━━━━━━━━━━ 23/23 4.9s/it 1:524.1ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 2.9s/it 5.7s<11.2s
#                    all         55         61      0.671      0.803      0.803      0.413
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       12/50         0G     0.9276     0.7912       1.35         25        640: 100% ━━━━━━━━━━━━ 23/23 4.9s/it 1:524.1ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 3.0s/it 5.9s<11.7s
#                    all         55         61      0.856      0.705      0.811      0.488
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       13/50         0G     0.9512     0.8126      1.367         28        640: 100% ━━━━━━━━━━━━ 23/23 4.8s/it 1:514.1sss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 2.9s/it 5.9s<11.3s
#                    all         55         61      0.431      0.607      0.477        0.2
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       14/50         0G     0.8902     0.7854      1.343         22        640: 100% ━━━━━━━━━━━━ 23/23 4.8s/it 1:504.0sss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 2.9s/it 5.8s<11.1s
#                    all         55         61      0.869      0.885      0.927      0.609
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       15/50         0G     0.8799     0.7223      1.317         20        640: 100% ━━━━━━━━━━━━ 23/23 4.9s/it 1:524.1ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 2.9s/it 5.8s<11.5s
#                    all         55         61      0.934      0.928      0.946      0.693
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       16/50         0G     0.8094     0.6248      1.247         36        640: 100% ━━━━━━━━━━━━ 23/23 4.8s/it 1:514.1ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 3.0s/it 5.9s<11.5s
#                    all         55         61      0.913      0.885      0.938      0.647
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       17/50         0G     0.8755     0.6546      1.313         25        640: 100% ━━━━━━━━━━━━ 23/23 4.8s/it 1:514.1ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 2.9s/it 5.8s<11.1s
#                    all         55         61      0.825      0.924      0.931       0.64
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       18/50         0G     0.8639     0.6777       1.29         24        640: 100% ━━━━━━━━━━━━ 23/23 4.8s/it 1:504.0sss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 2.9s/it 5.8s<11.5s
#                    all         55         61      0.897      0.754      0.891       0.59
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       19/50         0G     0.7801     0.6049      1.237         32        640: 100% ━━━━━━━━━━━━ 23/23 4.7s/it 1:494.0sss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 2.9s/it 5.7s<11.2s
#                    all         55         61      0.861      0.852      0.912      0.634
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       20/50         0G      0.781     0.6376      1.246         26        640: 100% ━━━━━━━━━━━━ 23/23 4.7s/it 1:494.0sss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 2.9s/it 5.8s<11.1s
#                    all         55         61      0.959      0.885      0.963      0.681
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       21/50         0G     0.7716     0.6117      1.243         31        640: 100% ━━━━━━━━━━━━ 23/23 4.8s/it 1:494.0sss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 2.9s/it 5.9s<11.3s
#                    all         55         61      0.782      0.934      0.926       0.65
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       22/50         0G     0.7529     0.5912      1.232         28        640: 100% ━━━━━━━━━━━━ 23/23 4.8s/it 1:504.0sss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 2.9s/it 5.7s<11.0s
#                    all         55         61       0.94      0.885      0.938      0.621
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       23/50         0G     0.7378     0.5956      1.208         28        640: 100% ━━━━━━━━━━━━ 23/23 4.8s/it 1:504.0sss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 2.8s/it 5.7s<11.0s
#                    all         55         61      0.912      0.853      0.949      0.673
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       24/50         0G     0.7272     0.5788      1.211         23        640: 100% ━━━━━━━━━━━━ 23/23 4.9s/it 1:524.2ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 3.0s/it 6.0s<11.6s
#                    all         55         61      0.928      0.934      0.967      0.712
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       25/50         0G     0.7393     0.5839      1.227         27        640: 100% ━━━━━━━━━━━━ 23/23 4.8s/it 1:514.0sss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 2.9s/it 5.9s<11.6s
#                    all         55         61       0.93      0.871      0.938       0.66
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       26/50         0G     0.6852     0.5322       1.18         20        640: 100% ━━━━━━━━━━━━ 23/23 4.9s/it 1:524.1ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 2.9s/it 5.8s<11.2s
#                    all         55         61      0.914      0.918      0.937      0.734
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       27/50         0G     0.7105     0.5333      1.202         21        640: 100% ━━━━━━━━━━━━ 23/23 4.8s/it 1:504.1sss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 2.9s/it 5.8s<11.1s
#                    all         55         61      0.915      0.852      0.942      0.681
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       28/50         0G     0.6972     0.5197      1.186         28        640: 100% ━━━━━━━━━━━━ 23/23 5.1s/it 1:574.4ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 3.2s/it 6.5s<13.1s
#                    all         55         61      0.905      0.984      0.966      0.726
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       29/50         0G     0.6938     0.5064      1.188         18        640: 100% ━━━━━━━━━━━━ 23/23 5.2s/it 1:594.3ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 3.0s/it 6.1s<12.2s
#                    all         55         61      0.871      0.902      0.944      0.728
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       30/50         0G     0.6523     0.5025      1.159         24        640: 100% ━━━━━━━━━━━━ 23/23 5.0s/it 1:544.3ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 2.9s/it 5.8s<11.2s
#                    all         55         61       0.93      0.918      0.964      0.755
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       31/50         0G     0.6443      0.515      1.156         24        640: 100% ━━━━━━━━━━━━ 23/23 5.0s/it 1:544.1ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 2.9s/it 5.8s<11.1s
#                    all         55         61      0.951      0.953      0.981      0.727
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       32/50         0G     0.6473     0.4989      1.149         27        640: 100% ━━━━━━━━━━━━ 23/23 4.9s/it 1:534.2sss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 2.9s/it 5.8s<11.2s
#                    all         55         61      0.983      0.924      0.981      0.736
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       33/50         0G     0.6204     0.4738      1.127         21        640: 100% ━━━━━━━━━━━━ 23/23 4.8s/it 1:504.0sss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 2.9s/it 5.9s<11.2s
#                    all         55         61      0.951       0.95      0.964      0.731
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       34/50         0G     0.6092     0.4639      1.129         28        640: 100% ━━━━━━━━━━━━ 23/23 4.7s/it 1:494.1sss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 2.9s/it 5.8s<11.4s
#                    all         55         61      0.931      0.951      0.965      0.757
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       35/50         0G     0.6062     0.4639      1.143         26        640: 100% ━━━━━━━━━━━━ 23/23 4.7s/it 1:494.0sss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 2.8s/it 5.7s<11.0s
#                    all         55         61      0.908      0.869      0.949      0.745
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       36/50         0G     0.6022     0.4724      1.134         23        640: 100% ━━━━━━━━━━━━ 23/23 4.7s/it 1:494.0sss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 2.9s/it 5.8s<11.3s
#                    all         55         61      0.993      0.869      0.945       0.72
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       37/50         0G     0.5823     0.4454      1.096         33        640: 100% ━━━━━━━━━━━━ 23/23 4.7s/it 1:484.0sss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 2.8s/it 5.6s<10.9s
#                    all         55         61      0.982      0.869      0.965       0.78
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       38/50         0G     0.5954     0.4632      1.122         25        640: 100% ━━━━━━━━━━━━ 23/23 4.7s/it 1:483.9sss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 2.8s/it 5.7s<11.0s
#                    all         55         61      0.904       0.93      0.972      0.758
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       39/50         0G     0.5882     0.4385      1.119         25        640: 100% ━━━━━━━━━━━━ 23/23 4.7s/it 1:484.0sss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 2.8s/it 5.7s<11.0s
#                    all         55         61      0.896      0.934      0.968       0.75
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       40/50         0G     0.5653     0.4208      1.102         27        640: 100% ━━━━━━━━━━━━ 23/23 4.7s/it 1:484.0sss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 2.8s/it 5.6s<10.9s
#                    all         55         61      0.981      0.951      0.968      0.743
# Closing dataloader mosaic
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       41/50         0G      0.387     0.3231      1.017         11        640: 100% ━━━━━━━━━━━━ 23/23 4.7s/it 1:473.9sss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 2.9s/it 5.7s<11.2s
#                    all         55         61      0.948      0.934      0.951       0.73
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       42/50         0G     0.3633     0.2735     0.9866         10        640: 100% ━━━━━━━━━━━━ 23/23 4.7s/it 1:484.0sss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 2.8s/it 5.6s<10.9s
#                    all         55         61       0.93      0.918      0.949       0.75
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       43/50         0G     0.3532     0.2556     0.9745         10        640: 100% ━━━━━━━━━━━━ 23/23 4.7s/it 1:484.0sss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 2.8s/it 5.6s<11.0s
#                    all         55         61      0.979      0.951       0.96      0.737
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       44/50         0G     0.3455     0.2461     0.9779         13        640: 100% ━━━━━━━━━━━━ 23/23 4.7s/it 1:484.0sss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 2.8s/it 5.7s<11.0s
#                    all         55         61      0.935      0.946      0.965      0.763
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       45/50         0G     0.3379     0.2407     0.9863         10        640: 100% ━━━━━━━━━━━━ 23/23 4.7s/it 1:484.1sss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 2.8s/it 5.6s<10.9s
#                    all         55         61      0.957      0.918      0.965      0.752
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       46/50         0G     0.3366     0.2415     0.9689         10        640: 100% ━━━━━━━━━━━━ 23/23 4.7s/it 1:483.9sss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 2.9s/it 5.8s<11.0s
#                    all         55         61      0.975      0.918      0.966      0.759
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       47/50         0G     0.3217     0.2279     0.9582         10        640: 100% ━━━━━━━━━━━━ 23/23 4.7s/it 1:484.0sss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 2.9s/it 5.7s<11.4s
#                    all         55         61       0.92      0.951      0.963      0.777
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       48/50         0G      0.309     0.2127     0.9499         11        640: 100% ━━━━━━━━━━━━ 23/23 4.9s/it 1:534.1ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 2.8s/it 5.7s<11.0s
#                    all         55         61       0.95      0.933      0.964      0.778
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       49/50         0G     0.2972     0.2103     0.9183         10        640: 100% ━━━━━━━━━━━━ 23/23 4.9s/it 1:524.0ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 2.8s/it 5.6s<10.9s
#                    all         55         61      0.966      0.934      0.966      0.782
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       50/50         0G      0.306     0.2161       0.94         12        640: 100% ━━━━━━━━━━━━ 23/23 4.7s/it 1:483.9sss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 2.9s/it 5.8s<11.4s
#                    all         55         61      0.965      0.934      0.967      0.777
#
# 50 epochs completed in 1.626 hours.
# Optimizer stripped from /home/jean/dev/ai_project/Stib4All/detection/yolov8_custom/weights/last.pt, 22.5MB
# Optimizer stripped from /home/jean/dev/ai_project/Stib4All/detection/yolov8_custom/weights/best.pt, 22.5MB
#
# Validating /home/jean/dev/ai_project/Stib4All/detection/yolov8_custom/weights/best.pt...
# Ultralytics 8.3.232 🚀 Python-3.12.3 torch-2.9.1+cu128 CPU (AMD Ryzen 5 7600X 6-Core Processor)
# Model summary (fused): 72 layers, 11,125,971 parameters, 0 gradients, 28.4 GFLOPs
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 2.5s/it 5.1s9.9s
#                    all         55         61      0.966      0.934      0.966      0.782
# Speed: 0.8ms preprocess, 89.5ms inference, 0.0ms loss, 0.2ms postprocess per image
# Results saved to /home/jean/dev/ai_project/Stib4All/detection/yolov8_custom
# ✓ Training completed!
# Results saved to: yolov8_custom

# %%
# Load the best trained model
# After training, the best model is saved as 'best.pt'
best_model_path = PROJECT_DIR / 'yolov8_custom' / 'weights' / 'best.pt'

# Check if model exists
if best_model_path.exists():
    model = YOLO(str(best_model_path))
    print(f"Loaded fine-tuned model from: {best_model_path}")
    
    # Validate the model on the validation set
    metrics = model.val(data=str(yaml_path))
    
    # Display metrics
    print("\n" + "="*50)
    print("Validation Metrics")
    print("="*50)
    print(f"mAP50: {metrics.box.map50:.4f}")        # mAP at IoU=0.50
    print(f"mAP50-95: {metrics.box.map:.4f}")       # mAP at IoU=0.50:0.95
    print(f"Precision: {metrics.box.mp:.4f}")       # Mean precision
    print(f"Recall: {metrics.box.mr:.4f}")          # Mean recall
    print("="*50)
else:
    print(f"Model not found at: {best_model_path}")
    print("Please train the model first!")
    print("\nFor demonstration, you can load the pre-trained model:")
    model = YOLO('yolov8n.pt')
# Out:
# Loaded fine-tuned model from: yolov8_custom/weights/best.pt
# Ultralytics 8.3.232 🚀 Python-3.12.3 torch-2.9.1+cu128 CPU (AMD Ryzen 5 7600X 6-Core Processor)
# Model summary (fused): 72 layers, 11,125,971 parameters, 0 gradients, 28.4 GFLOPs
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 2513.2±975.2 MB/s, size: 46.9 KB)
# val: Scanning /home/jean/dev/ai_project/Stib4All/detection/Wheelchair-1/test/labels.cache... 55 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 55/55 109.0Kit/s 0.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 4/4 1.2s/it 4.9s2.1ss
#                    all         55         61      0.966      0.934      0.966      0.782
# Speed: 0.6ms preprocess, 85.7ms inference, 0.0ms loss, 0.2ms postprocess per image
# Results saved to /home/jean/dev/ai_project/runs/detect/val2
#
# ==================================================
# Validation Metrics
# ==================================================
# mAP50: 0.9657
# mAP50-95: 0.7823
# Precision: 0.9661
# Recall: 0.9336
# ==================================================
